# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a,b=map(int, input().split())
print(a*b, 2*(a+b))

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r=float(input())
print(3.14*r**2,2*3.14*r)

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
import triangle 
a,b,c=map(float, input().split())
if triangle.bool_tri(a,b,c):
    print(triangle.type_tri(a,b,c))
    p=(a+b+c)/2
    print((p*(p-a)*(p-b)*(p-c))**0.5,a+b+c)
else:
    print('Khong la ba canh cua mot tam giac')
# Out:
# Tam giác vuông
# 6.0 12.0

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b=map(int,input().split())
if a==0 and b==0:
    print('Phuong trinh co vo so nghiem')
elif a==0 and b!=0:
    print('Phuong trinh vo nghiem')
else:
    print('Phuong trinh co nghiem duy nhat x=',-b/a)

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c=map(float, input().split())
if a==0:
    if b==0 and c==0:
        print('Phuong trinh co vo so nghiem')
    elif b==0 and c!=0:
        print('Phuong trinh vo nghiem')
    elif b!=0 and c==0:
        print('Phuong trinh co nghiem duy nhat x=0')
    else:
        print('Phuong trinh co nghiem duy nhat x=',-c/b)
else:
    delta=b**2-4*a*c
    if delta<0:
        print('Phuong trinh vo nghiem')
    elif delta==0:
        print('Phuong trinh co nghiem kep x=',-b/(2*a))
    else:
        print('Phuong trinh co hai nghiem phan biet x1=',(-b-delta**0.5)/(2*a),'x2=',(-b+delta**0.5)/(2*a))
# Out:
# Phuong trinh co nghiem kep x= -1.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
A=[]
for i in range(4):
    A.append(int(input()))
m=A[0]
for k in range(1,4):
    if A[k]>m:
        m=A[k]
print(m)
# Out:
# 7

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
A=[]
for i in range(4):
    A.append(int(input()))
m=A[0]
for k in range(1,4):
    if A[k]<m:
        m=A[k]
print(m)
# Out:
# 3

# %% [markdown]
# #### Bài 8: Giải hệ phương trình tuyến tính:
# ax+by=m
# cx+dy=n

# %%
a,b,m,c,d,n=map(int, input().split())
x=0
y=0
i=c/a

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %% [markdown]
# Bài 11: Tính x^y (với x và y là số thực)
